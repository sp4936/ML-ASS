# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
Dataset=pd.read_csv('Mall_Customers.csv')

# %%
Dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X=Dataset.iloc[:,[3,4]].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(
        n_clusters=i,
        init='k-means++',
        max_iter=300,
        random_state=0,
        algorithm='elkan'
    )
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(15,5))
plt.plot(range(1,11),wcss,marker='o',linestyle='-',color='blue')
plt.title('Elbow Curve')
plt.xlabel('cluster')
plt.ylabel('Wcss')
plt.show()

# %%
kmeans=KMeans(n_clusters=5,init='k-means++',max_iter=300,random_state=0,algorithm='elkan')
ymeans=kmeans.fit_predict(X)

# %%
plt.scatter(X[ymeans==0,0],X[ymeans==0,1],s=100,color='red',label='Cluster1')
plt.scatter(X[ymeans==1,0],X[ymeans==1,1],s=100,color='blue',label='Cluster1')
plt.scatter(X[ymeans==2,0],X[ymeans==2,1],s=100,color='pink',label='Cluster1')
plt.scatter(X[ymeans==3,0],X[ymeans==3,1],s=100,color='green',label='Cluster1')
plt.scatter(X[ymeans==4,0],X[ymeans==4,1],s=100,color='yellow',label='Cluster1')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,color='black')
plt.title('Kmeans Clusturing ')
plt.xlabel('Income')
plt.ylabel('Spending score')
plt.show()
